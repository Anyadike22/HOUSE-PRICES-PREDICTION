# %%
# Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#LOAD THE DATA

# %%
data = pd.read_csv("housing.csv")

# %%
##EXPLORATORY DATA ANALYSIS

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
#DROP NULL VALUES

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
# PRE-PROCESSING

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data['total_rooms'] = np.log(data['total_rooms'] + 1)
data['total_bedrooms'] = np.log(data['total_bedrooms'] + 1)
data['population'] = np.log(data['population'] + 1)
data['households'] = np.log(data['households'] + 1)

# %%
data.hist(figsize = (15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# ONE-HOT ENCODING OF THE CATEGORICAL DATA

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7488     -118.22     33.92                43.0     7.086738        5.549076
# 8248     -118.19     33.78                42.0     6.929517        5.707110
# 18907    -122.26     38.14                34.0     6.871091        5.075174
# 247      -122.22     37.77                40.0     6.204558        4.744932
# 12913    -121.32     38.62                33.0     6.801283        5.252273
# ...          ...       ...                 ...          ...             ...
# 14709    -117.07     32.79                25.0     7.820038        5.752573
# 13100    -121.39     38.43                 3.0     7.899895        5.953243
# 11147    -117.98     33.84                35.0     6.892642        5.192957
# 20583    -122.00     38.73                31.0     5.918894        4.317488
# 645      -122.13     37.72                26.0     7.959625        5.978886
#
#        population  households  median_income ocean_proximity  \
# 7488     7.132498    5.572154         3.4539       <1H OCEAN
# 8248     6.280396    5.236442         1.8036      NEAR OCEAN
# 18907    5.973810    5.176150         4.0156        NEAR BAY
# 247      6.306275    4.912655         2.8015        NEAR BAY
# 12913    6.154858    5.308268         2.6897          INLAND
# ...           ...         ...            ...             ...
# 14709    6.815640    5.736572         7.8336      NEAR OCEAN
# 13100    6.898715    5.758902         5.4445          INLAND
# 11147    6.495266    5.298317         5.0747       <1H OCEAN
# 20583    5.342334    4.442651         3.8750          INLAND
# 645      6.938284    5.986452         7.9120        NEAR BAY
#
#        median_house_value
# 7488             125000.0
# 8248             175000.0
# 18907            134700.0
# 247              114800.0
# 12913            148300.0
# ...                   ...
# 14709            277600.0
# 13100            237600.0
# 11147            189600.0
# 20583            137500.0
# 645              367300.0
#
# [16346 rows x 10 columns]

# %%
new_data = data.join(pd.get_dummies(data.ocean_proximity).astype(int))

# %%
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0     6.781058        4.867534
# 1        -122.22     37.86                21.0     8.867850        7.009409
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 3        -122.25     37.85                52.0     7.150701        5.463832
# 4        -122.25     37.85                52.0     7.395108        5.638355
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0     7.418181        5.926926
# 20636    -121.21     39.49                18.0     6.548219        5.017280
# 20637    -121.22     39.43                17.0     7.720905        6.186209
# 20638    -121.32     39.43                18.0     7.528869        6.016157
# 20639    -121.24     39.37                16.0     7.932362        6.424869
#
#        population  households  median_income  median_house_value  \
# 0        5.777652    4.844187         8.3252            452600.0
# 1        7.784057    7.037906         8.3014            358500.0
# 2        6.208590    5.181784         7.2574            352100.0
# 3        6.326149    5.393628         5.6431            341300.0
# 4        6.338594    5.560682         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635    6.740519    5.802118         1.5603             78100.0
# 20636    5.877736    4.744932         2.5568             77100.0
# 20637    6.915723    6.073045         1.7000             92300.0
# 20638    6.609349    5.857933         1.8672             84700.0
# 20639    7.235619    6.274762         2.3886             89400.0
#
#       ocean_proximity  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0            NEAR BAY          0       0       0         1           0
# 1            NEAR BAY          0       0       0         1           0
# 2            NEAR BAY          0       0       0         1           0
# 3            NEAR BAY          0       0       0         1           0
# 4            NEAR BAY          0       0       0         1           0
# ...               ...        ...     ...     ...       ...         ...
# 20635          INLAND          0       1       0         0           0
# 20636          INLAND          0       1       0         0           0
# 20637          INLAND          0       1       0         0           0
# 20638          INLAND          0       1       0         0           0
# 20639          INLAND          0       1       0         0           0
#
# [20433 rows x 15 columns]

# %%
new_data = data.join(pd.get_dummies(data.ocean_proximity).astype(int)).drop(['ocean_proximity'], axis=1)

# %%
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0     6.781058        4.867534
# 1        -122.22     37.86                21.0     8.867850        7.009409
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 3        -122.25     37.85                52.0     7.150701        5.463832
# 4        -122.25     37.85                52.0     7.395108        5.638355
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0     7.418181        5.926926
# 20636    -121.21     39.49                18.0     6.548219        5.017280
# 20637    -121.22     39.43                17.0     7.720905        6.186209
# 20638    -121.32     39.43                18.0     7.528869        6.016157
# 20639    -121.24     39.37                16.0     7.932362        6.424869
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0        5.777652    4.844187         8.3252            452600.0          0
# 1        7.784057    7.037906         8.3014            358500.0          0
# 2        6.208590    5.181784         7.2574            352100.0          0
# 3        6.326149    5.393628         5.6431            341300.0          0
# 4        6.338594    5.560682         3.8462            342200.0          0
# ...           ...         ...            ...                 ...        ...
# 20635    6.740519    5.802118         1.5603             78100.0          0
# 20636    5.877736    4.744932         2.5568             77100.0          0
# 20637    6.915723    6.073045         1.7000             92300.0          0
# 20638    6.609349    5.857933         1.8672             84700.0          0
# 20639    7.235619    6.274762         2.3886             89400.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0           0       0         1           0
# 1           0       0         1           0
# 2           0       0         1           0
# 3           0       0         1           0
# 4           0       0         1           0
# ...       ...     ...       ...         ...
# 20635       1       0         0           0
# 20636       1       0         0           0
# 20637       1       0         0           0
# 20638       1       0         0           0
# 20639       1       0         0           0
#
# [20433 rows x 14 columns]

# %%
#FEATURE ENGINEERING

# %%
new_data['bedroom_ratio'] = new_data['total_bedrooms'] / new_data['total_rooms']

new_data['household_rooms'] = new_data['total_rooms'] / new_data['households']

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(new_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
#SPLIT DATA AND TRAINING THE MODEL

# %%
from sklearn.model_selection import train_test_split

X = new_data.drop(['median_house_value'], axis=1)
y = new_data['median_house_value']

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
X_train, y_train = new_data.drop(['median_house_value'], axis=1), new_data['median_house_value']

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.671122278452847

# %%
# ENSEMBLE MODEL

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_train, y_train)
# Out:
# 0.9754676588027827

# %%
# TEST THE MODEL WITH UNSEEN DATE

# %%
# Use the trained model to predict on the test features
y_pred = model.predict(X_test)

# %%
 #Get the score for the test data
score = model.score(X_test, y_test)
print(f"Model Score on Test Data: {score}")
# Out:
# Model Score on Test Data: 0.6769846069048151
